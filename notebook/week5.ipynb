# %%
import os

files = [
    "main.py",
    "predict.py",
    "vector_db.py",
    "embedding_pipeline.py",
    "semantic_search.py",
    "metadata_pipeline.py",
    "ingest.py",
    "test_api.py",
    "test_predict.py",
    "performance_test.py",
    "requirements.txt",
    "README.md",
    "week5_performance.json",
]

print("=== Week 5 Final File Check ===\n")
all_exist = True
for file in files:
    exists = os.path.exists(file)
    if not exists:
        all_exist = False
    size = os.path.getsize(file) if exists else 0
    print(f"{'EXISTS' if exists else 'MISSING'} — {file} ({size:,} bytes)")

print()
if all_exist:
    print("All Week 5 files present ")
    print("Ready for Week 6 — LLM Integration and RAG")
else:
    print("Some files missing — fix before Week 6")
